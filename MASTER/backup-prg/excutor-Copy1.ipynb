# %% [raw]
# %run main.py

# %%
import pickle

with open(f'./data/self_exp/opensource/csi500_self_dl_train.pkl', 'rb') as f:
    dl_train = pickle.load(f)

# %%
import pickle

with open(f'./handler_20080101_20250325.pkl', 'rb') as f:
    data = pickle.load(f)

# %%
dl_train.data
# Out:
#                                    feature                     \
#                       ($close-$open)/$open ($high-$low)/$open
# datetime   instrument
# 2008-01-02 SH600039               0.514046           0.686973
#            SH600051               3.000000           2.615869
#            SH600054               1.300209           1.180003
#            SH600056               3.000000           2.745063
#            SH600057               0.713873           1.062943
# ...                                    ...                ...
# 2022-09-30 SZ300741              -0.849001           0.211675
#            SZ300769              -1.435385           0.294795
#            SZ300832               0.302572          -0.270267
#            SZ300869              -0.520277          -0.247468
#            SZ300888               0.669938          -0.030710
#
#                                                          \
#                       ($close-$open)/($high-$low+1e-12)
# ...

# %%
metrics
# Out:
# {'IC': 0.05308860930056739,
#  'ICIR': 0.3361851916229186,
#  'RIC': 0.06462063976484468,
#  'RICIR': 0.40803155564495114}

# %%
pred_frame = predictions.to_frame()
pred_frame.columns = ['score']
pred_frame.reset_index(inplace=True)
pred_frame.to_csv('master_predictions_csi300_0.csv', index=False, date_format='%Y-%m-%d')

# %%
pred_frame.to_csv(f'master_predictions_{universe}_{seed}.csv', index=False, date_format='%Y-%m-%d')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 pred_frame.to_csv(f'master_predictions_{universe}_{seed}.csv', index=False, date_format='%Y-%m-%d')
#
# NameError: name 'pred_frame' is not defined

# %%
# !python3 predict_and_send_result.py
# Out:
# Data Loaded.
# Model Loaded from model/20250228_train_from_2008_to_2022/csi300_opensource_self_exp_2_2.pkl
# self.fitted: Previously trained.
# /home/a/notebook/MASTER/base_model.py:40: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   self.daily_count = pd.Series(index=self.data_source.get_index()).groupby("datetime").size().values
# datetime    instrument
# 2023-01-03  SH600000      0.275206
#             SH600009      0.105019
#             SH600010      0.125788
#             SH600011      0.008515
#             SH600015      0.220468
#                             ...
# 2025-03-25  SZ300782     -0.158395
#             SZ300832      0.115477
#             SZ300896     -0.210205
#             SZ300979      0.343475
#             SZ300999      0.004218
# Length: 161054, dtype: float32
# ...

# %%
from datetime import datetime
