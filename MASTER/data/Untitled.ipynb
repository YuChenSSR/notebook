# %%
import pickle
import pandas as pd

with open(f'./opensource/daily_predict/csi800_self_dl_valid.pkl', 'rb') as f:
    dl_data = pickle.load(f)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 4
#       1 import pickle
#       2 import pandas as pd
# ----> 4 with open(f'./opensource/daily_predict/csi800_self_dl_valid.pkl', 'rb') as f:
#       5     dl_data = pickle.load(f)
#
# File ~/.conda/envs/pytorch/lib/python3.10/site-packages/IPython/core/interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: './opensource/daily_predict/csi800_self_dl_valid.pkl'

# %%
import torch
print(f"GPU memory allocated: {torch.cuda.memory_allocated()/1024**3:.2f} GB")
print(f"GPU memory cached: {torch.cuda.memory_reserved()/1024**3:.2f} GB")
# Out:
# GPU memory allocated: 0.00 GB
# GPU memory cached: 0.00 GB

# %%
dl_data.data
# Out:
#                         feature                                    \
#                           $turn $turn_week $turn_month $turn_year
# datetime   instrument
# 2023-12-20 SH600000   -1.051096  -1.076112   -1.103795  -1.205083
#            SH600004   -0.494745  -0.588346   -0.643444  -0.535793
#            SH600008   -0.703878  -0.713256   -0.761716  -0.633791
#            SH600009   -0.751559  -0.707435   -0.734309  -0.613692
#            SH600010   -0.251267  -0.333171   -0.388136  -0.646991
# ...                         ...        ...         ...        ...
# 2024-12-31 SZ301269    1.356889   1.573074    2.532610   0.107099
#            SZ301301    1.724171   1.428840    2.871050   3.000000
#            SZ301308    3.000000   3.000000    3.000000   3.000000
#            SZ301358    2.313568   1.205678    1.507625   1.148884
#            SZ301498   -0.159683   0.003725    0.378811   1.722776
#
#                                                                       \
# ...

# %%
for col in dl_data.data.columns:
    print(col)
print(len(dl_data.data.columns))
# Out:
# ('feature', '$turn')
# ('feature', '$turn_week')
# ('feature', '$turn_month')
# ('feature', '$turn_year')
# ('feature', '$turn_current_year')
# ('feature', '$pe_ratio_ttm')
# ('feature', '$pb_ratio_ttm')
# ('feature', '$ps_ratio_ttm')
# ('feature', '$peg_ratio_ttm')
# ('feature', '$market_cap')
# ('feature', '($close-$open)/$open')
# ('feature', '($high-$low)/$open')
# ('feature', '($close-$open)/($high-$low+1e-12)')
# ('feature', '($high-Greater($open, $close))/$open')
# ('feature', '($high-Greater($open, $close))/($high-$low+1e-12)')
# ('feature', '(Less($open, $close)-$low)/$open')
# ('feature', '(Less($open, $close)-$low)/($high-$low+1e-12)')
# ('feature', '(2*$close-$high-$low)/$open')
# ('feature', '(2*$close-$high-$low)/($high-$low+1e-12)')
# ('feature', '($pe_ratio_ttm*10000)/($volume+1e-12)')
# ('feature', '($pb_ratio_ttm*10000)/($volume+1e-12)')
# ('feature', '($ps_ratio_ttm*10000)/($volume+1e-12)')
# ('feature', '($peg_ratio_ttm*10000)/($volume+1e-12)')
# ...
