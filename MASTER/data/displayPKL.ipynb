# %%
import pickle
import sys

# %%
with open('/home/idc2/notebook/futures/data/futures_results/f88_20260113_20100104_20251212/f88_self_dl_test.pkl', 'rb') as file:
    data = pickle.load(file)

# %%
# with open('../self_exp/opensource/csi800_self_dl_train.pkl', 'rb') as file:
#     data = pickle.load(file)

# %%
display(data.shape)
# Out:
# (19379, 164)

# %%
names = list(data.columns)
names
# Out:
# [('feature', 'KBAR_RET'),
#  ('feature', 'KBAR_RANGE'),
#  ('feature', 'KBAR_BODY_RATIO'),
#  ('feature', 'KBAR_UPPER_SHADOW'),
#  ('feature', 'KBAR_UPPER_SHADOW_RATIO'),
#  ('feature', 'KBAR_LOWER_SHADOW'),
#  ('feature', 'KBAR_LOWER_SHADOW_RATIO'),
#  ('feature', 'KBAR_CLV'),
#  ('feature', 'KBAR_CLV_RATIO'),
#  ('feature', 'OPEN'),
#  ('feature', 'HIGH'),
#  ('feature', 'LOW'),
#  ('feature', 'VWAP'),
#  ('feature', 'LOG_VOLUME'),
#  ('feature', 'LOG_AMOUNT'),
#  ('feature', 'ROC_5'),
#  ('feature', 'MA_5'),
#  ('feature', 'STD_5'),
#  ('feature', 'BETA_5'),
#  ('feature', 'RSQR_5'),
#  ('feature', 'RESI_5'),
#  ('feature', 'RANK_5'),
#  ('feature', 'CORR_5'),
#  ('feature', 'CORD_5'),
#  ('feature', 'CNTP_5'),
#  ('feature', 'CNTN_5'),
#  ('feature', 'CNTD_5'),
#  ('feature', 'SUMP_5'),
#  ('feature', 'SUMN_5'),
#  ('feature', 'SUMD_5'),
#  ('feature', 'VMA_5'),
#  ('feature', 'VSTD_5'),
#  ('feature', 'ROC_10'),
#  ('feature', 'MA_10'),
#  ('feature', 'STD_10'),
# ...

# %%
# with open('../../handler_20120101_20251030.pkl', 'rb') as file:
#     data = pickle.load(file)

# %%
display(data.shape)
# Out:
# (19379, 164)

# %%
# data['datetime'] == '2025-06-10'
# data
# datetime
data[data[key_date] == '2025-06-10']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 4
#       1 # data['datetime'] == '2025-06-10'
#       2 # data
#       3 # datetime
# ----> 4 data[data[key_date] == '2025-06-10']
#
# NameError: name 'key_date' is not defined

# %%
data.loc['2025-06-10']
# Out:
#              feature                                               \
#             KBAR_RET KBAR_RANGE KBAR_BODY_RATIO KBAR_UPPER_SHADOW
# instrument
# A88         2.305072   0.724810        1.319854          0.467223
# AD88       -1.460750   0.790989       -0.810331          0.685426
# AG88       -0.197110   0.411473       -0.133149          3.000000
# AL88       -0.638598  -0.496917       -0.900733         -0.433763
# AO88       -0.928725   0.250130       -0.691343          0.588965
# ...              ...        ...             ...               ...
# WH88        0.000000  -1.331799        0.000000         -0.790307
# WR88        0.122975  -0.691771        0.226261         -0.094582
# Y88        -0.243090  -0.691015       -0.446733          0.093776
# ZC88        0.000000  -1.331799        0.000000         -0.790307
# ZN88       -0.614937  -0.502608       -0.873311         -0.725094
#
#                                                                               \
# ...

# %%
# 1. 查看索引结构
print("索引类型:", type(data.index))
print("索引名称:", data.index.names)
print("索引前5行:\n", data.index[:5])
# Out:
# 索引类型: <class 'pandas.core.indexes.multi.MultiIndex'>
# 索引名称: ['datetime', 'instrument']
# 索引前5行:
#  MultiIndex([('2025-01-02',  'A88'),
#             ('2025-01-02', 'AG88'),
#             ('2025-01-02', 'AL88'),
#             ('2025-01-02', 'AO88'),
#             ('2025-01-02', 'AP88')],
#            names=['datetime', 'instrument'])
