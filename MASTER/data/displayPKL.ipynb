# %%
import pickle
import sys

# %%
with open('./opensource/csi800_self_dl_test.pkl', 'rb') as file:
    data = pickle.load(file)

# %%
with open('../daily_predict/opensource/csi800_self_dl_train.pkl', 'rb') as file:
    data = pickle.load(file)

# %%
display(data.data.shape)
# Out:
# (1751135, 520)

# %%
names = list(data.data.columns)
names
# Out:
# [('feature', '$turn'),
#  ('feature', '$turn_week'),
#  ('feature', '$turn_month'),
#  ('feature', '$turn_year'),
#  ('feature', '$turn_current_year'),
#  ('feature', '$pe_ratio_ttm'),
#  ('feature', '$pb_ratio_ttm'),
#  ('feature', '$ps_ratio_ttm'),
#  ('feature', '$peg_ratio_ttm'),
#  ('feature', '($close-$open)/$open'),
#  ('feature', '($high-$low)/$open'),
#  ('feature', '($close-$open)/($high-$low+1e-12)'),
#  ('feature', '($high-Greater($open, $close))/$open'),
#  ('feature', '($high-Greater($open, $close))/($high-$low+1e-12)'),
#  ('feature', '(Less($open, $close)-$low)/$open'),
#  ('feature', '(Less($open, $close)-$low)/($high-$low+1e-12)'),
#  ('feature', '(2*$close-$high-$low)/$open'),
#  ('feature', '(2*$close-$high-$low)/($high-$low+1e-12)'),
#  ('feature', '($buy_volume*2-$volume)/($volume+1e-12)'),
#  ('feature', '(($buy_amount*2-$amount)*10000)/($market_cap+1e-12)'),
#  ('feature', '$volume*10000/($num_trades+1e-12)/($market_cap/($close+1e-12))'),
# ...

# %%
with open('../../handler_20120101_20251030.pkl', 'rb') as file:
    data = pickle.load(file)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 with open('../../handler_20120101_20251030.pkl', 'rb') as file:
#       2     data = pickle.load(file)
#
# File ~/.conda/envs/pytorch/lib/python3.10/site-packages/IPython/core/interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../../handler_20120101_20251030.pkl'

# %%
display(data.data.shape)
# Out:
# (2305995, 524)

# %%
data.data
# Out:
#                         feature                                    \
#                           $turn $turn_week $turn_month $turn_year
# datetime   instrument
# 2015-01-05 SH600033    0.624081   0.106653    1.177450  -0.703077
#            SH600051    0.832038   0.134815    0.615239  -0.261374
#            SH600055    0.169617  -0.431072   -0.193040  -0.058090
#            SH600057    1.222532   0.242164    1.999663   0.245214
#            SH600061    3.000000   2.997427    3.000000   0.256171
# ...                         ...        ...         ...        ...
# 2024-06-28 SZ301510    3.000000   2.996311    2.931383   3.000000
#            SZ301511    3.000000   3.000000    3.000000   3.000000
#            SZ301526    1.386469   2.333811    1.504144   3.000000
#            SZ301558    1.377452   2.053865    2.373028   3.000000
#            SZ301559   -0.457092  -0.328462   -0.065068   1.412580
#
#                                                                       \
# ...
